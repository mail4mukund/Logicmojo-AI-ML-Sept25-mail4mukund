# %%
import numpy as np

# %%
arr_oneD=np.array([1,2,4,55,67])
arr_oneD
# Out:
# array([ 1,  2,  4, 55, 67])

# %%
arr_2D=np.array([[1,2,4,55,67],[3,5,3,23,6]])
arr_2D
# Out:
# array([[ 1,  2,  4, 55, 67],
#        [ 3,  5,  3, 23,  6]])

# %%
arr_3D=np.array([[[1,2,4,55,67],[3,5,3,23,6]],
                 
                 )
arr_3D
